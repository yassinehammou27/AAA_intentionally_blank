# %% [markdown]
# <a href="https://colab.research.google.com/github/yassinehammou27/AAA_intentionally_blank/blob/prep/prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data preparation AAA

# %%
import pandas as pd
import os  
os.makedirs('./data', exist_ok=True)

# %% [markdown]
# API taken from the Open-Meteo Historical Weather API. For further details and the documentation click the link [here](https://open-meteo.com/en/docs/historical-weather-api)

# %%
location_data =  pd.read_csv('https://archive-api.open-meteo.com/v1/archive?latitude=41.85&longitude=-87.65&start_date=2016-01-01&end_date=2016-12-31&temperature_2m,relativehumidity_2m,apparent_temperature,surface_pressure,precipitation,cloudcover,windspeed_10m&format=csv&timezone=CST', nrows=1)
weather_data_hourly = pd.read_csv('https://archive-api.open-meteo.com/v1/archive?latitude=41.85&longitude=-87.65&start_date=2016-01-01&end_date=2016-12-31&hourly=temperature_2m,relativehumidity_2m,apparent_temperature,surface_pressure,precipitation,cloudcover,windspeed_10m&format=csv&timezone=CST', header=2)
weather_data_daily= pd.read_csv('https://archive-api.open-meteo.com/v1/archive?latitude=41.85&longitude=-87.65&start_date=2016-01-01&end_date=2016-12-31&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,apparent_temperature_max,apparent_temperature_min,apparent_temperature_mean,sunrise,sunset,precipitation_sum,precipitation_hours,windspeed_10m_max&format=csv&timezone=CST', header=2)

# %%
weather_data_hourly.to_csv('data/weather_data_daily.csv')
weather_data_hourly
# Out:
#                   time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0     2016-01-01T00:00                 -4.0                       71
# 1     2016-01-01T01:00                 -3.9                       72
# 2     2016-01-01T02:00                 -3.6                       71
# 3     2016-01-01T03:00                 -3.9                       71
# 4     2016-01-01T04:00                 -4.5                       73
# ...                ...                  ...                      ...
# 8779  2016-12-31T19:00                  0.6                       61
# 8780  2016-12-31T20:00                  0.0                       65
# 8781  2016-12-31T21:00                 -0.6                       69
# 8782  2016-12-31T22:00                 -1.2                       71
# 8783  2016-12-31T23:00                 -1.6                       73
#
#       apparent_temperature (°C)  surface_pressure (hPa)  precipitation (mm)  \
# ...

# %%
weather_data_hourly.to_csv('data/weather_data_hourly.csv')
weather_data_daily
# Out:
#            time  temperature_2m_max (°C)  temperature_2m_min (°C)  \
# 0    2016-01-01                     -0.5                     -6.2
# 1    2016-01-02                      1.4                     -4.1
# 2    2016-01-03                     -0.3                     -3.0
# 3    2016-01-04                     -0.5                     -3.1
# 4    2016-01-05                      1.3                     -4.8
# ..          ...                      ...                      ...
# 361  2016-12-27                     -0.2                     -3.4
# 362  2016-12-28                      5.5                     -3.4
# 363  2016-12-29                      1.9                     -0.4
# 364  2016-12-30                      0.9                     -2.7
# 365  2016-12-31                      3.9                     -1.6
#
#      temperature_2m_mean (°C)  apparent_temperature_max (°C)  \
# 0                        -3.2                           -6.7
# ...

# %%
location_data.to_csv('data/location_data.csv')
location_data
# Out:
#     latitude  longitude  elevation  utc_offset_seconds         timezone  \
# 0  41.800003      -87.6      179.0              -18000  America/Chicago
#
#   timezone_abbreviation
# 0                   CDT
